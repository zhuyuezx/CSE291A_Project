# %% [markdown]
# # Sokoban MCTS + LLM Optimization Pipeline
#
# All configuration comes from two files in `MCTS_tools/`:
# 1. **`hyperparams/default_hyperparams.py`** — engine params (iterations,
#    max_rollout_depth, exploration_weight), game identity, and optimization
#    settings (phases, num_iters, etc.)
# 2. **`training_logic/sokoban_training.py`** — levels, mastery criteria,
#    level-selection strategy
#
# The orchestrator (`OptimizationRunner.from_config()`) reads both files
# and drives the iterative LLM optimization loop.

# %% [markdown]
# ## Cell 1: Setup — add Tool_Creation to sys.path & import orchestrator

# %%
import sys
from pathlib import Path

# Ensure Tool_Creation is on sys.path (parent of orchestrator/)
ROOT = Path(".").resolve().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from orchestrator import OptimizationRunner, Evaluator
from mcts import MCTSEngine
from mcts.games import Sokoban

print(f"Working dir: {Path('.').resolve()}")
print(f"Tool_Creation root: {ROOT}")
print("All imports OK ✓")
# Out:
# Working dir: /Users/zhuyuezx/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/orchestrator
# Tool_Creation root: /Users/zhuyuezx/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation
# All imports OK ✓

# %% [markdown]
# ## Cell 2: Play one baseline game (sanity check)
#
# Quick check that the engine works before launching the optimization loop.

# %%
import importlib.util

# Load hyperparams module (single source of config)
_hp_path = ROOT / "MCTS_tools" / "hyperparams" / "default_hyperparams.py"
_spec = importlib.util.spec_from_file_location("hp", str(_hp_path))
_mod = importlib.util.module_from_spec(_spec)
_spec.loader.exec_module(_mod)
hp = _mod.get_hyperparams()

ITERS = hp["iterations"]
MAX_DEPTH = hp["max_rollout_depth"]
MAX_STEPS = hp["iterations"]
PHASES = _mod.PHASES

# Load training logic to get start level
_tl_path = ROOT / "MCTS_tools" / "training_logic" / f"{_mod.TRAINING_LOGIC}.py"
_spec2 = importlib.util.spec_from_file_location("tl", str(_tl_path))
_tl_mod = importlib.util.module_from_spec(_spec2)
_spec2.loader.exec_module(_tl_mod)
LEVEL = _tl_mod.START_LEVEL

game = Sokoban(LEVEL, max_steps=MAX_STEPS)
engine = MCTSEngine(game, iterations=ITERS, max_rollout_depth=MAX_DEPTH, logging=True)
baseline = engine.play_game()

base_tag = "SOLVED" if baseline.get("solved") else "UNSOLVED"
print(f"Baseline ({LEVEL}): {base_tag} in {baseline.get('steps', '?')} steps  "
      f"returns={baseline.get('returns', '?')}")
print(f"Hyperparams: iterations={ITERS}, max_depth={MAX_DEPTH}, "
      f"C={hp.get('exploration_weight', 1.41)}")
print(f"Optimize phases: {PHASES}")
print(f"Trace: {baseline.get('log_file', 'N/A')}")
# Out:
# Baseline (level4): SOLVED in 14 steps  returns=[1.0]
# Hyperparams: iterations=200, max_depth=500, C=1.41
# Optimize phases: ['simulation', 'expansion']
# Trace: /Users/zhuyuezx/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/mcts/records/Sokoban (level4)_20260310_185458_996816.json

# %% [markdown]
# ## Cell 3: Run iterative optimization
#
# Create the `OptimizationRunner` from the hyperparams module and run the
# full loop. Engine params, game identity, and optimization settings all
# come from `MCTS_tools/hyperparams/default_hyperparams.py`. Training
# strategy comes from `MCTS_tools/training_logic/`.

# %%
runner = OptimizationRunner.from_config(verbose=True)
summary = runner.run()

best_fns = summary["best_fns"]
print(f"\nbest_fns: { {p: ('set' if f else 'None') for p, f in best_fns.items()} }")
print(f"Final hyperparams: {summary.get('current_hyperparams', {})}")
# Out:
# Starting level: level4
# Hyperparams: iterations=200, max_depth=500, C=1.410
# Phases to optimize: ['simulation', 'expansion']
#   Computing baseline for level4…
#     level4: composite=1.0000, solve_rate=100%, avg_returns=1.0000 (0.3s)
#   ⏳ level4 hit 100% on 3 runs — confirming with 7 more games…
#   🎓 level4 MASTERED — 10/10 solved (0.4s)
#   Reject floor for level4: 0.5000
#   Active levels: ['level4', 'level5', 'level6', 'level7', 'level8']
#
# ############################################################
#   ITERATION 1/5, LEVEL=level4, PHASE=simulation
#   Baseline composite=1.0000, reject_floor=0.5000
#   Active levels: 5/5, mastered: ['level4']
# ############################################################
#   Play: SOLVED in 10 steps  returns=1.0000  (0.1s)
#   TraceAnalyzer: analyzing play trace…
#   TraceAnalyzer: **1. OUTCOME SUMMARY**
# - **Result:** The episode solved the level in **10 moves** (reward = 1.0).
# - **Final board:**
#
# ```
# #######
# #     #
# #   @ #
# # * * #
# #######
# ```
#
# The player ( @ ) ends on the empty floor at row 3, col 4 (0‑based inside the inner area). Both boxes are on the two target squares ( * ) in the bottom row.
#
# ---
#
# **2. KEY MOMENTS**
#
# | Move | Description | Why it matters |
# |------|-------------|----------------|
# | **2** (action = 2 ← LEFT) | After stepping left onto the target (+) the player positions himself directly behind the left‑most box. This sets up a clean push line. | Creates the first “push‑ready” alignment without wandering, keeping the distance metric low. |
# | **5** (action = 3 → RIGHT) | The player moves right along the top corridor, clearing the lower‑left corner for the upcoming push. | Prevents the box from being boxed into the wall and opens a straight path to the first target. |
# | **7** (action = 0 ↑) | The player pushes the left box upward onto its target (box → *). Boxes‑on‑target jumps from 0→1, distance drops from 2→1. | decisive tactical push; the high visit‑value (v=164, q=0.671) shows the MCTS correctly identified the critical gain. |
#
# A minor but still positive moment is **8–9** (continuous right moves) where the player slides to the far side, keeping the second box free for the final push.
#
# ---
#
# **3. ROOT CAUSE**
# The solution stems from **excellent early positioning** combined with a **focused push sequence**. By moving left in Move 2 the agent placed the player directly behind a box, then cleared the corridor (Move 5) and executed a clean push (Move 7). The MCTS consistently selected actions with the highest visit counts, indicating that the search tree already favored the correct line of play. No dead‑lock was approached, so exploration did not need to correct a mistake.
#
# ---
#
# **4. SIMULATION HEURISTIC INSIGHT**
# The rollout (simulation) heuristic should **penalize pushes that increase box‑to‑target Manhattan distance** and **detect simple dead‑locks** (box in a non‑target corner or against a wall with no target along that wall). Adding a small bonus for “pushes that reduce distance by ≥ 1” would amplify the signal for moves like Move 7, making the tree expand those branches faster and reducing reliance on raw visit counts. This targeted distance‑aware rollout would help MCTS prioritize productive pushes earlier in larger levels.
# Step 1/6: Building analysis prompt…
# Step 2/6: Querying LLM (step 2 — draft code)…
# Step 3/6: Querying LLM (step 3 — critique & finalize)…
#   LLM query: status=success  elapsed=26.02s
#   Step-1 analysis length: 4924 chars
# Step 5/6: Parsing & validating response…
#   Validation passed ✓
#   Installed to: /Users/zhuyuezx/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/MCTS_tools/simulation/simulation.py
# Step 6/6: Smoke testing…
#   Smoke test failed: name '_sample_weighted_action' is not defined. Attempting repair (1/1)…
#   Smoke test passed ✓
#   Optimize (simulation): 36.1s
#   Eval (3 runs, level4): avg_returns=1.0000, solve_rate=100%, composite=1.0000, avg_steps=11  (1.2s)
#   → Accepted on level4 (comp=1.0000 ≥ floor=0.5000)
#   Iteration total: 37.4s
#   Computing baseline for level8…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 runner = OptimizationRunner.from_config(verbose=True)
# ----> 2 summary = runner.run()
#       4 best_fns = summary["best_fns"]
#       5 print(f"\nbest_fns: { {p: ('set' if f else 'None') for p, f in best_fns.items()} }")
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/orchestrator/runner.py:740, in OptimizationRunner.run(self)
#     737     break
#     739 cur_level = current_level
# --> 740 bl = ev.get_baseline(cur_level)
#     741 reject_floor = bl["composite"] * self.reject_threshold
#     742 opt_phase = self._pick_optimization_phase(iteration)
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/orchestrator/evaluator.py:192, in Evaluator.get_baseline(self, level)
#     190 if level not in self.level_baselines:
#     191     print(f"  Computing baseline for {level}…")
# --> 192     avg, sr, steps, _, t = self.multi_eval(None, level)
#     193     comp = self.composite_score(sr, avg)
#     194     self.level_baselines[level] = {
#     195         "avg_returns": avg,
#     196         "solve_rate": sr,
#    (...)    199         "composite": comp,
#     200     }
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/orchestrator/evaluator.py:135, in Evaluator.multi_eval(self, fn, level, n, logging, phase, extra_tools)
#     133             if f is not None:
#     134                 e.set_tool(p, f)
# --> 135     r = e.play_game()
#     136     results.append(r)
#     137 elapsed = time.time() - t0
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/mcts/mcts_engine.py:319, in MCTSEngine.play_game(self, verbose)
#     306     self._logger.begin_game({
#     307         "game": self.game.name(),
#     308         "timestamp": datetime.now().isoformat(),
#    (...)    315         },
#     316     })
#     318 while not state.is_terminal():
# --> 319     root, action = self._search_internal(state)
#     321     # Record move trace if logging
#     322     if self.logging and self._logger is not None:
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/mcts/mcts_engine.py:274, in MCTSEngine._search_internal(self, root_state)
#     271     node = child
#     273 # 3. Simulation -- random rollout from the node
# --> 274 reward = simulate_fn(
#     275     node.state,
#     276     root_state.current_player(),
#     277     self.max_rollout_depth,
#     278 )
#     280 # 4. Backpropagation -- update stats from leaf to root
#     281 backprop_fn(node, reward)
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/MCTS_tools/simulation/default_simulation.py:25, in default_simulation(state, perspective_player, max_depth)
#      23 sim_state = state.clone()
#      24 depth = 0
# ---> 25 while not sim_state.is_terminal() and depth < max_depth:
#      26     action = random.choice(sim_state.legal_actions())
#      27     sim_state.apply_action(action)
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/mcts/games/sokoban.py:210, in SokobanState.is_terminal(self)
#     209 def is_terminal(self) -> bool:
# --> 210     if self._is_solved():
#     211         return True
#     212     if self.steps >= self.max_steps:
#
# File ~/Documents/UCSD/Winter_2025/CSE291A/CSE291A_Project/Tool_Creation/mcts/games/sokoban.py:231, in SokobanState._is_solved(self)
#     230 def _is_solved(self) -> bool:
# --> 231     return self.boxes == set(self.targets)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Cell 4: Multi-Level Evaluation
#
# Run both **baseline** (default MCTS) and **best LLM-optimized** function
# across all levels to measure generalization.

# %%
best_fns = summary["best_fns"]
levels   = summary["active_levels"] + list(summary.get("mastered_levels", []))
ev       = runner.evaluator

# Build extra_tools from best_fns for optimized eval
opt_tools = {p: f for p, f in best_fns.items() if f is not None} or None

has_optimized = opt_tools is not None
print(f"Best fns: { {p: ('set' if f else 'None') for p, f in best_fns.items()} }")
print(f"Final hyperparams: {summary.get('current_hyperparams', {})}")
print(f"Mastered: {sorted(summary.get('mastered_levels', set()))}")
print(f"Level best scores: {summary.get('level_best_scores', {})}")

if not has_optimized:
    print("\nNo optimized functions adopted — skipping comparative eval.")
else:
    # Only eval on levels visited during optimization (have baselines)
    eval_levels = sorted(ev.level_baselines.keys())
    print(f"\nEvaluating {len(eval_levels)} levels (n=3 each)…")

    rows = []
    for lvl in eval_levels:
        avg_b, sr_b, steps_b, _, t_b = ev.multi_eval(None, lvl, n=3, logging=False)
        avg_o, sr_o, steps_o, _, t_o = ev.multi_eval(
            None, lvl, n=3, logging=False, extra_tools=opt_tools,
        )
        rows.append((lvl, sr_b, sr_o, avg_b, avg_o, steps_b, steps_o, t_b, t_o))
        print(f"{lvl}: baseline={avg_b:.3f} ({sr_b:.0%})  optimized={avg_o:.3f} ({sr_o:.0%})  "
              f"[{t_b:.1f}s + {t_o:.1f}s]")

    print(f"\n{'Level':<10} {'Base Solve%':>12} {'Opt Solve%':>12} "
          f"{'Base AvgRet':>12} {'Opt AvgRet':>12} "
          f"{'Base Steps':>11} {'Opt Steps':>11}")
    print("─" * 82)
    for lvl, sr_b, sr_o, avg_b, avg_o, steps_b, steps_o, *_ in rows:
        print(f"{lvl:<10} {sr_b*100:>11.0f}% {sr_o*100:>11.0f}% "
              f"{avg_b:>12.3f} {avg_o:>12.3f} "
              f"{steps_b:>11.1f} {steps_o:>11.1f}")
# Out:
# Best fns: {'simulation': 'set', 'expansion': 'None'}
# Final hyperparams: {'iterations': 1000, 'max_rollout_depth': 130, 'exploration_weight': 2.0}
# Mastered: ['level2', 'level4', 'level5']
# Level best scores: {'level6': 0.0, 'level4': 1.0, 'level2': 1.0, 'level5': 1.0, 'level10': 0.6666666666666666}
#
# Evaluating 5 levels (n=3 each)…
# level10: baseline=0.000 (0%)  optimized=0.333 (33%)  [57.2s + 479.8s]
# level2: baseline=1.000 (100%)  optimized=1.000 (100%)  [0.1s + 0.4s]
# level4: baseline=1.000 (100%)  optimized=1.000 (100%)  [0.5s + 4.6s]
# level5: baseline=1.000 (100%)  optimized=0.667 (67%)  [24.1s + 383.8s]
# level6: baseline=0.000 (0%)  optimized=0.000 (0%)  [18.5s + 27.4s]
#
# Level       Base Solve%   Opt Solve%  Base AvgRet   Opt AvgRet  Base Steps   Opt Steps
# ──────────────────────────────────────────────────────────────────────────────────
# level10              0%          33%        0.000        0.333       200.0       196.0
# level2             100%         100%        1.000        1.000         3.0         3.0
# level4             100%         100%        1.000        1.000         8.0        10.0
# level5             100%          67%        1.000        0.667        97.0       188.7
# level6               0%           0%        0.000        0.000       200.0       200.0
